# %%
import numpy as np 
import pandas as pd 
import scipy.stats as stat
value1 = {
    'Name':['Rahul','Himanshu','Priya','Satish','Payal','Ganesh','Hitesh','Ram','Shyam','Priya','Divyansh','Arjit','Aaditya','Shiv',
            'Mridul','Manav','Jayesh','Rahi','Yash','Pankaj'],
    'Category':['IT','Sales','Business','Athical Hacking','Devolopar','IT','Devolopar','SQL','Business','Java','VBA','IT','Sales','Business',
    'Athical Hacking','Devolopar','IT','Devolopar','Java','Business'],
    'Salary':[45000,35000,50000,30000,60000,52000,65000,74000,62000,76000,80000,85000,83000,75000,61000,90000,93000,80000,96000,57000],
    'Experience_Year':[2,3,5,4,4,2,5,1,6,3,8,4,4,2,5,2,3,3,7,1]
}

df = pd.DataFrame(value1)
df
# Out:
#         Name         Category  Salary  Experience_Year
# 0      Rahul               IT   45000                2
# 1   Himanshu            Sales   35000                3
# 2      Priya         Business   50000                5
# 3     Satish  Athical Hacking   30000                4
# 4      Payal        Devolopar   60000                4
# 5     Ganesh               IT   52000                2
# 6     Hitesh        Devolopar   65000                5
# 7        Ram              SQL   74000                1
# 8      Shyam         Business   62000                6
# 9      Priya             Java   76000                3
# 10  Divyansh              VBA   80000                8
# 11     Arjit               IT   85000                4
# 12   Aaditya            Sales   83000                4
# 13      Shiv         Business   75000                2
# 14    Mridul  Athical Hacking   61000                5
# 15     Manav        Devolopar   90000                2
# ...

# %%
it_salary = df[df['Category']=='IT']['Salary']
dev_salary = df[df['Category']=='Devoloper']['Salary']
it_salary
dev_salary
# Out:
# Series([], Name: Salary, dtype: int64)

# %%
t_test,p_value = stat.ttest_ind(it_salary,dev_salary)
alpha = 0.05
print(f"T-test{t_test}")
print(f"P-value{p_value}")
if p_value < alpha:
    print("Result: Hypothesis Rejected")
else:
    print("Result: Hypothesis not Rejected")
# Out:
# T-testnan
# P-valuenan
# Result: Hypothesis not Rejected

# %%
print([[t_test,p_value]])
# Out:
# [[np.float64(nan), np.float64(nan)]]

# %%
df.info
df.isna
df.count
# Out:
# <bound method DataFrame.count of         Name         Category  Salary  Experience_Year
# 0      Rahul               IT   45000                2
# 1   Himanshu            Sales   35000                3
# 2      Priya         Business   50000                5
# 3     Satish  Athical Hacking   30000                4
# 4      Payal        Devolopar   60000                4
# 5     Ganesh               IT   52000                2
# 6     Hitesh        Devolopar   65000                5
# 7        Ram              SQL   74000                1
# 8      Shyam         Business   62000                6
# 9      Priya             Java   76000                3
# 10  Divyansh              VBA   80000                8
# 11     Arjit               IT   85000                4
# 12   Aaditya            Sales   83000                4
# 13      Shiv         Business   75000                2
# 14    Mridul  Athical Hacking   61000                5
# ...

# %%
df.groupby('Category')['Salary'].describe()
# Out:
#                  count     mean           std      min      25%      50%  \
# Category
# Athical Hacking    2.0  45500.0  21920.310217  30000.0  37750.0  45500.0
# Business           4.0  61000.0  10551.461194  50000.0  55250.0  59500.0
# Devolopar          4.0  73750.0  13768.926368  60000.0  63750.0  72500.0
# IT                 4.0  68750.0  23781.995991  45000.0  50250.0  68500.0
# Java               2.0  86000.0  14142.135624  76000.0  81000.0  86000.0
# SQL                1.0  74000.0           NaN  74000.0  74000.0  74000.0
# Sales              2.0  59000.0  33941.125497  35000.0  47000.0  59000.0
# VBA                1.0  80000.0           NaN  80000.0  80000.0  80000.0
#
#                      75%      max
# Category
# Athical Hacking  53250.0  61000.0
# Business         65250.0  75000.0
# Devolopar        82500.0  90000.0
# IT               87000.0  93000.0
# Java             91000.0  96000.0
# SQL              74000.0  74000.0
# Sales            71000.0  83000.0
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(7,3))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Java_Salary = df[df['Category']=='Java']['Salary']
it_salary = df[df['Category']=='IT']['Salary'] 
t_test,p_value = stat.ttest_ind(t_test,p_value,alternative='greater')
print(f"Statistic-test{t_test}")
print(f"P-value{p_value}")
alpha = 0.05
if p_value < alpha:
    print("Result: Hypothesis Rejected")
else:
    print("Result: Hypothesis not Rejected")
# Out:
# Statistic-testnan
# P-valuenan
# Result: Hypothesis not Rejected

# %%
plt.figure(figsize=(8,4))
filtered_df = df[df['Category'].isin(['Java','IT'])]
sns.kdeplot(data=filtered_df,x='Salary',hue='Category',fill=True,palette='Set1',alpha=0.4)
plt.title("Java vs IT Salary Distribution",fontsize=12,fontweight='bold')
plt.xlabel("Salary")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxenplot(data=filtered_df,x='Category',y='Salary',palette='Pastel1')
plt.title("Java vs IT Salary Comparison", fontsize=12,fontweight='bold')
plt.xlabel("Department")
plt.ylabel("Salary")
plt.show()
# Out:
# C:\Users\sonid\AppData\Local\Temp\ipykernel_5576\2318873372.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data=filtered_df,x='Category',y='Salary',palette='Pastel1')
